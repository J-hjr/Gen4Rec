# %%
import sqlite3, pandas as pd
conn = sqlite3.connect("music4all.db")
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;", conn)
tables
# Out:
#                 name
# 0          id_genres
# 1     id_information
# 2            id_lang
# 3        id_metadata
# 4            id_tags
# 5  listening_history

# %%
df = pd.read_sql("SELECT * FROM listening_history", conn)
df.head()
# Out:
#             user              song         timestamp
# 0  user_007XIjOr  DaTQ53TUmfP93FSr  2019-02-20 12:28
# 1  user_007XIjOr  dGeyvi5WCOjDU7da  2019-02-20 12:35
# 2  user_007XIjOr  qUm54NYOjeFhmKYx  2019-02-20 12:48
# 3  user_007XIjOr  FtnuMT1DlevSR2n5  2019-02-20 12:52
# 4  user_007XIjOr  LHETTZcSZLeaVOGh  2019-02-20 13:09

# %%
conn = sqlite3.connect("music4all_final.sqlite")
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;", conn)
tables
# Out:
#           name
# 0     final_db
# 1  musical_new

# %%
test = pd.read_sql("SELECT * FROM final_db", conn)
test
# Out:
#                       id                                         musical_db  \
# 0       0009fFIM1eYThaPg  [0.07604348659515381, 0.00861547701060772, -0....
# 1       0010xmHR6UICBOYT  [0.07058699429035187, 0.01870115101337433, -0....
# 2       002Jyd0vN4HyCpqL  [0.07372468709945679, 0.016590703278779984, -0...
# 3       006TYKNjNxWjfKjy  [0.07935899496078491, 0.031098611652851105, -0...
# 4       007LIJOPQ4Sb98qV  [0.06902480125427246, 0.027448248118162155, -0...
# ...                  ...                                                ...
# 109264  zzyyPUs7hC9Nz2e1  [0.05122791975736618, 0.03276118263602257, -0....
# 109265  zzz0n04uuTUA7fNh  [0.08093161880970001, 0.02886452153325081, -0....
# 109266  zzzj3LYaZtYtbzSr  [0.07240122556686401, 0.024198895320296288, -0...
# 109267  zzznMjZAKnJJXQSj  [0.05921902135014534, 0.011026952415704727, -0...
# 109268  zzzwh2ktIWjsR7xp  [0.06550147384405136, 0.032227590680122375, -0...
#
#                                                lyrical_db  \
# 0       [-0.0033781668171286583, 0.011112084612250328,...
# 1       [0.05815385654568672, -0.009112397208809853, 0...
# 2       [-0.03389301523566246, 0.032592788338661194, 0...
# 3       [-0.05854003131389618, -0.03212481737136841, 0...
# 4       [-0.002691638423129916, -0.018016116693615913,...
# ...                                                   ...
# 109264  [0.03249511495232582, 0.010329384356737137, -0...
# 109265  [-0.028081415221095085, -0.024841494858264923,...
# 109266  [-0.007332625333219767, 0.0028875891584903, -0...
# 109267  [-0.0525948591530323, 0.004303360357880592, -0...
# 109268  [0.0036885032895952463, -0.008996081538498402,...
#
#                              song_name  \
# 0                           Rain on Me
# 1                       After Thoughts
# 2                               ME 262
# 3                    Flames of Revenge
# 4                            Nostalgia
# ...                                ...
# 109264                        Vampires
# 109265                    Heartbreaker
# 109266      Après Moi - Live In London
# 109267  New Rules (Initial Talk Remix)
# 109268                      In the End
#
#                                                     album  \
# 0                                                 3 Words
# 1                                       The Beauty in All
# 2                                         Secret Treaties
# 3                           Legendary Years (Re-Recorded)
# 4       What Does Anything Mean? Basically (2009 Remas...
# ...                                                   ...
# 109264                                        Modern Ruin
# 109265                                           Journals
# 109266                                     Live In London
# 109267                     New Rules (Initial Talk Remix)
# 109268                                     Fallen Empires
#
#                                  artist  \
# 0                                Cheryl
# 1                               Oddisee
# 2                      Blue Öyster Cult
# 3                              Rhapsody
# 4                        The Chameleons
# ...                                 ...
# 109264  Frank Carter & The Rattlesnakes
# 109265                    Justin Bieber
# 109266                   Regina Spektor
# 109267                         Dua Lipa
# 109268                      Snow Patrol
#
#                                               semantic_db
# 0       [0.0978178009390831,-0.0061011482030153275,0.0...
# 1       [-0.054971594363451004,-0.03325279802083969,-0...
# 2       [-0.054807618260383606,0.004959520883858204,-0...
# 3       [0.03915850818157196,-0.062305912375450134,0.0...
# 4       [-0.05041821300983429,-0.10588043928146362,0.0...
# ...                                                   ...
# 109264  [-0.018610823899507523,0.04963809996843338,0.0...
# 109265  [0.004074763040989637,-0.028319930657744408,-0...
# 109266  [0.013253732584416866,0.07186240702867508,0.07...
# 109267  [-0.008234084583818913,0.046497445553541183,-0...
# 109268  [-0.05869755521416664,0.10847461223602295,-0.0...
#
# [109269 rows x 7 columns]
